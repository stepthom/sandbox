# %% [markdown]
# # Playground for Association Rule Learning slides
#
# - Stephen W. Thomas
# - Used for MMA 869, MMAI 869, and GMMA 869

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns 

from sklearn.metrics import silhouette_score, silhouette_samples
import sklearn.metrics
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, DBSCAN, AgglomerativeClustering
from sklearn.mixture import GaussianMixture
from sklearn.metrics import accuracy_score, cohen_kappa_score, f1_score, log_loss
from sklearn.model_selection import train_test_split
from sklearn.datasets import make_classification

import itertools

import scipy

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # Example of converting lists into a dataframe

# %%
dataset = [['Milk', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Dill', 'Onion', 'Nutmeg', 'Kidney Beans', 'Eggs', 'Yogurt'],
           ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
           ['Milk', 'Unicorn', 'Corn', 'Kidney Beans', 'Yogurt'],
           ['Corn', 'Onion', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']]

import pandas as pd
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df1 = pd.DataFrame(te_ary, columns=te.columns_)
df1
# Out:
#    Apple   Corn   Dill   Eggs  Ice cream  Kidney Beans   Milk  Nutmeg  Onion  \
# 0  False  False  False   True      False          True   True    True   True
# 1  False  False   True   True      False          True  False    True   True
# 2   True  False  False   True      False          True   True   False  False
# 3  False   True  False  False      False          True   True   False  False
# 4  False   True  False   True       True          True  False   False   True
#
#    Unicorn  Yogurt
# 0    False    True
# 1    False    True
# 2    False   False
# 3     True    True
# 4    False   False

# %% [markdown]
# # Read in Data

# %%
df = pd.read_csv('data/groceries.csv')
df.head()
# Out:
#    frankfurter  sausage  liver loaf    ham   meat  finished products  \
# 0        False    False       False  False  False              False
# 1        False    False       False  False  False              False
# 2        False    False       False  False  False              False
# 3        False    False       False  False  False              False
# 4        False    False       False  False  False              False
#
#    organic sausage  chicken  turkey   pork  ...    candles  light bulbs  \
# 0            False    False   False  False  ...      False        False
# 1            False    False   False  False  ...      False        False
# 2            False    False   False  False  ...      False        False
# 3            False    False   False  False  ...      False        False
# 4            False    False   False  False  ...      False        False
#
#    sound storage medium  newspapers  photo/film  pot plants  \
# 0                 False       False       False       False
# 1                 False       False       False       False
# 2                 False       False       False       False
# 3                 False       False       False       False
# 4                 False       False       False       False
#
#    flower soil/fertilizer  flower (seeds)  shopping bags   bags
# 0                   False           False          False  False
# 1                   False           False          False  False
# 2                   False           False          False  False
# 3                   False           False          False  False
# 4                   False           False          False  False
#
# [5 rows x 169 columns]

# %%
from mlxtend.frequent_patterns import apriori

# %time frequent_itemsets = apriori(df, min_support=0.001, use_colnames=True)
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(lambda x: len(x))
# Out:
# Wall time: 16.6 s

# %%
frequent_itemsets.head(10)
# Out:
#     support             itemsets  length
# 0  0.058973        (frankfurter)       1
# 1  0.093950            (sausage)       1
# 2  0.005084         (liver loaf)       1
# 3  0.026029                (ham)       1
# 4  0.025826               (meat)       1
# 5  0.006507  (finished products)       1
# 6  0.002237    (organic sausage)       1
# 7  0.042908            (chicken)       1
# 8  0.008134             (turkey)       1
# 9  0.057651               (pork)       1

# %%
frequent_itemsets.tail(10)
# Out:
#         support                                           itemsets  length
# 13482  0.001118  (beef, other vegetables, root vegetables, trop...       6
# 13483  0.001423  (other vegetables, root vegetables, yogurt, tr...       6
# 13484  0.001017  (other vegetables, root vegetables, yogurt, ci...       6
# 13485  0.001322  (other vegetables, root vegetables, yogurt, tr...       6
# 13486  0.001118  (other vegetables, root vegetables, yogurt, bu...       6
# 13487  0.001118  (other vegetables, root vegetables, yogurt, tr...       6
# 13488  0.001322  (other vegetables, root vegetables, yogurt, tr...       6
# 13489  0.001017  (oil, other vegetables, root vegetables, yogur...       6
# 13490  0.001118  (bottled water, other vegetables, root vegetab...       6
# 13491  0.001017  (other vegetables, yogurt, butter, tropical fr...       6

# %%
frequent_itemsets[ (frequent_itemsets['length'] == 2) &
                   (frequent_itemsets['support'] >= 0.02) ]
# Out:
#        support                                   itemsets  length
# 173   0.020539                  (whole milk, frankfurter)       2
# 255   0.026945                (sausage, other vegetables)       2
# 257   0.029893                      (whole milk, sausage)       2
# 281   0.030605                      (rolls/buns, sausage)       2
# 303   0.024301                            (sausage, soda)       2
# 551   0.021657                   (pork, other vegetables)       2
# 553   0.022166                         (whole milk, pork)       2
# 627   0.021251                         (whole milk, beef)       2
# 762   0.028876           (citrus fruit, other vegetables)       2
# 764   0.030503                 (citrus fruit, whole milk)       2
# 769   0.021657                     (citrus fruit, yogurt)       2
# 847   0.020437                (tropical fruit, pip fruit)       2
# 850   0.021047          (root vegetables, tropical fruit)       2
# 853   0.035892         (tropical fruit, other vegetables)       2
# 855   0.042298               (whole milk, tropical fruit)       2
# 860   0.029283                   (yogurt, tropical fruit)       2
# 881   0.024606               (rolls/buns, tropical fruit)       2
# 913   0.020844                     (tropical fruit, soda)       2
# 951   0.026131              (pip fruit, other vegetables)       2
# 952   0.030097                    (whole milk, pip fruit)       2
# 1132  0.047382        (root vegetables, other vegetables)       2
# 1134  0.048907              (root vegetables, whole milk)       2
# 1139  0.025826                  (root vegetables, yogurt)       2
# 1160  0.024301              (root vegetables, rolls/buns)       2
# 1298  0.074835             (whole milk, other vegetables)       2
# 1299  0.020031                 (butter, other vegetables)       2
# 1303  0.043416                 (yogurt, other vegetables)       2
# 1304  0.028876     (whipped/sour cream, other vegetables)       2
# 1323  0.022267          (domestic eggs, other vegetables)       2
# 1324  0.042603             (rolls/buns, other vegetables)       2
# ...        ...                                        ...     ...
# 1361  0.024809          (bottled water, other vegetables)       2
# 1362  0.032740                   (soda, other vegetables)       2
# 1364  0.021047  (fruit/vegetable juice, other vegetables)       2
# 1407  0.023183          (shopping bags, other vegetables)       2
# 1424  0.027555                       (whole milk, butter)       2
# 1425  0.026131                         (whole milk, curd)       2
# 1428  0.056024                       (whole milk, yogurt)       2
# 1429  0.032232           (whole milk, whipped/sour cream)       2
# 1442  0.020437            (whole milk, frozen vegetables)       2
# 1448  0.029995                (domestic eggs, whole milk)       2
# 1449  0.056634                   (whole milk, rolls/buns)       2
# 1451  0.025216                  (whole milk, brown bread)       2
# 1452  0.033249                       (whole milk, pastry)       2
# 1463  0.024199                    (whole milk, margarine)       2
# 1491  0.034367                (whole milk, bottled water)       2
# 1492  0.040061                         (whole milk, soda)       2
# 1494  0.026640        (whole milk, fruit/vegetable juice)       2
# 1495  0.020437                 (whole milk, bottled beer)       2
# 1531  0.027351                   (whole milk, newspapers)       2
# 1535  0.024504                (whole milk, shopping bags)       2
# 1742  0.020742               (yogurt, whipped/sour cream)       2
# 1762  0.034367                       (yogurt, rolls/buns)       2
# 1796  0.022979                    (yogurt, bottled water)       2
# 1797  0.027351                             (yogurt, soda)       2
# 2358  0.020946                       (pastry, rolls/buns)       2
# 2387  0.024199                (rolls/buns, bottled water)       2
# 2388  0.038332                         (rolls/buns, soda)       2
# 2524  0.021047                             (pastry, soda)       2
# 2856  0.028978                      (bottled water, soda)       2
# 2928  0.024606                      (soda, shopping bags)       2
#
# [61 rows x 3 columns]

# %%
frequent_itemsets[ frequent_itemsets['itemsets'] == {'pastry', 'soda'} ]
# Out:
#        support        itemsets  length
# 2524  0.021047  (pastry, soda)       2

# %%
from mlxtend.frequent_patterns import association_rules
# %time rules = association_rules(frequent_itemsets, min_threshold=0.1)
# Out:
# Wall time: 422 ms

# %%
rules["antecedent_len"] = rules["antecedents"].apply(lambda x: len(x))
rules
# Out:
#                                              antecedents  \
# 0                                              (sausage)
# 1                                          (frankfurter)
# 2                                                 (meat)
# 3                                                 (pork)
# 4                                       (hamburger meat)
# 5                                          (frankfurter)
# 6                                          (frankfurter)
# 7                                          (frankfurter)
# 8                                          (frankfurter)
# 9                                               (onions)
# 10                                         (frankfurter)
# 11                                         (frankfurter)
# 12                                         (butter milk)
# 13                                         (frankfurter)
# 14                                         (frankfurter)
# 15                                         (soft cheese)
# 16                                    (processed cheese)
# 17                                          (mayonnaise)
# 18                                   (frozen vegetables)
# 19                                        (frozen meals)
# 20                                         (frozen fish)
# 21                                      (frozen dessert)
# 22                              (frozen potato products)
# 23                                       (domestic eggs)
# 24                                         (frankfurter)
# 25                                          (rolls/buns)
# 26                                         (frankfurter)
# 27                                         (white bread)
# 28                                         (brown bread)
# 29                                         (frankfurter)
# ...                                                  ...
# 43702  (domestic eggs, yogurt, butter, other vegetables)
# 43703     (yogurt, butter, whole milk, other vegetables)
# 43704  (domestic eggs, yogurt, tropical fruit, other ...
# 43705  (yogurt, tropical fruit, whole milk, other veg...
# 43706  (domestic eggs, yogurt, whole milk, other vege...
# 43707  (domestic eggs, tropical fruit, butter, other ...
# 43708  (whole milk, tropical fruit, butter, other veg...
# 43709  (domestic eggs, whole milk, butter, other vege...
# 43710  (domestic eggs, whole milk, tropical fruit, ot...
# 43711    (domestic eggs, yogurt, tropical fruit, butter)
# 43712       (yogurt, tropical fruit, butter, whole milk)
# 43713        (domestic eggs, yogurt, butter, whole milk)
# 43714  (domestic eggs, yogurt, tropical fruit, whole ...
# 43715  (domestic eggs, whole milk, tropical fruit, bu...
# 43716                 (yogurt, butter, other vegetables)
# 43717          (domestic eggs, yogurt, other vegetables)
# 43718         (tropical fruit, butter, other vegetables)
# 43719          (domestic eggs, butter, other vegetables)
# 43720  (domestic eggs, tropical fruit, other vegetables)
# 43721                   (yogurt, tropical fruit, butter)
# 43722                    (domestic eggs, yogurt, butter)
# 43723                       (yogurt, butter, whole milk)
# 43724            (domestic eggs, yogurt, tropical fruit)
# 43725                (domestic eggs, yogurt, whole milk)
# 43720            0.009354  0.001017    0.212766  22.745143  0.000972
# 43721            0.012303  0.001017    0.222222  18.062443  0.000960
# 43722            0.017082  0.001017    0.344828  20.186782  0.000966
# 43723            0.004779  0.001017    0.108696  22.745143  0.000972
# 43724            0.011490  0.001017    0.238095  20.722714  0.000968
# 43725            0.005491  0.001017    0.131579  23.964425  0.000974
# 43726            0.022267  0.001017    0.434783  19.525511  0.000965
# 43727            0.005796  0.001017    0.163934  28.285879  0.000981
# 43728            0.012303  0.001017    0.169492  13.776439  0.000943
# 43729            0.006406  0.001017    0.147059  22.957516  0.000972
# 43730            0.003355  0.001017    0.102041  30.411255  0.000983
# 43731            0.007626  0.001017    0.105263  13.803509  0.000943
#
#        conviction  antecedent_len
# 0        1.053950               1
# 1        1.092534               1
# 2        1.076670               1
# 3        1.048256               1
# 4        1.046652               1
# 5        1.031000               1
# 6        1.065995               1
# 7        1.053289               1
# 8        1.076627               1
# 9        1.070945               1
# 10       1.119077               1
# 11       1.142330               1
# 12       1.064948               1
# 13       1.061891               1
# 14       1.037426               1
# 15       1.082826               1
# 16       1.072639               1
# 17       1.114374               1
# 18       1.052259               1
# 19       1.050186               1
# 20       1.104266               1
# 21       1.072568               1
# 22       1.148606               1
# 23       1.058019               1
# 24       1.063015               1
# 25       1.050813               1
# 26       1.210531               1
# 27       1.073237               1
# 28       1.056999               1
# 29       1.063481               1
# ...           ...             ...
# 43702    2.325848               4
# 43703    1.288192               4
# 43704    1.856487               4
# 43705    1.142701               4
# 43706    1.420486               4
# 43707    2.292512               4
# 43708    1.414213               4
# 43709    1.456075               4
# 43710    1.478038               4
# 43711    4.009049               4
# 43712    1.402834               4
# 43713    1.767531               4
# 43714    1.495743               4
# 43715    2.152313               4
# 43716    1.180461               3
# 43717    1.205244               3
# 43718    1.217789               3
# 43719    1.266236               3
# 43720    1.258388               3
# 43721    1.269896               3
# 43722    1.500243               3
# 43723    1.116590               3
# 43724    1.297420               3
# 43725    1.145193               3
# 43726    1.729835               3
# 43727    1.189146               3
# 43728    1.189268               3
# 43729    1.164904               3
# 43730    1.109900               2
# 43731    1.109124               2
#
# [43732 rows x 10 columns]

# %%
rules[ (rules['antecedent_len'] >= 2) &
       (rules['confidence'] > 0.75) &
       (rules['lift'] > 1.2) ]
# Out:
#               antecedents consequents  antecedent support  consequent support  \
# 12  (Kidney Beans, Onion)      (Eggs)                 0.6                 0.8
#
#     support  confidence  lift  leverage  conviction  antecedent_len
# 12      0.6         1.0  1.25      0.12         inf               2

# %%
rules[ (rules['antecedents'].apply(lambda x: 'Eggs' in x)) & (rules['antecedent_len'] >=2) ]
# Out:
#              antecedents     consequents  antecedent support  \
# 10  (Kidney Beans, Eggs)         (Onion)                 0.8
# 11         (Onion, Eggs)  (Kidney Beans)                 0.6
#
#     consequent support  support  confidence  lift  leverage  conviction  \
# 10                 0.6      0.6        0.75  1.25      0.12    1.600000
# 11                 1.0      0.6        1.00  1.00      0.00         inf
#
#     antecedent_len
# 10               2
# 11               2
